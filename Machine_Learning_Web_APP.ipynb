# %%
# %%writefile EDA_WebAPP.py

# import Libraries

import streamlit as st
import numpy as np
import pandas as pd
import seaborn as sns
from pandas_profiling import ProfileReport
from streamlit_pandas_profiling import st_profile_report


# Header 

st.markdown('''
# **EDA WEB APP**
**In This Application, You can Analyze & Describe Data & Perform All  EDA Operations Easily by Just Uploading The Dataset**
''')


#Upload File From PC


with st.sidebar.header('Upload Your Dataset(.csv)'):
    uploaded_file = st.sidebar.file_uploader('Upload Your File', type=['csv', 'txt', 'xlsx'])
    df = sns.load_dataset('titanic')
    st.sidebar.markdown("[ExampleCSVFile](https://raw.githubusercontent.com/codebasics/py/master/pandas/11_melt/weather.csv)")
    
    
# Profiling Report For Pandas

if uploaded_file is not None:
    @st.cache
    def load_csv():
        csv = pd.read_csv(uploaded_file)
        return csv
    df= load_csv()
    pr =ProfileReport(df, explorative=True)
    st.header('1- **Input Data Frame**')
    st.write(df)
    st.write('---')
    st.header("2- **Profiling Report With Pandas**")
    st_profile_report(pr)
else:
    st.info('Waiting To Upload CSV File')
    if st.button('Press This Button To Use Example Dataset'):
        # Sample Dataset
        def load_csv():
            a = pd.DataFrame(np.random.rand(100,5), columns=['apple', 'ball', 'carrot', 'donkey', 'elephant'])
            return a
        df = load_csv()
        pr = ProfileReport(df, explorative=True)
        st.header("1- **Input Data Frame**")
        st.write(df)
        st.write('---')
        st.header("2- **Profiling Report With Pandas**")
        st_profile_report(pr)
# Out:
# Overwriting EDA_WebAPP.py

# %%
# %%writefile EDA_Web_Application.py

# Import Libraries
import streamlit as st
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport
from streamlit_pandas_profiling import st_profile_report


# Header of The APP

st.markdown('''
# **EDA WEB Application**

**Explore And Describe Dataset and Perform EDA Functionality By Uploading The Dataset**
''')


# Upload The File From PC

with st.sidebar.header('Upload Your Dataset.(.csv .txt)'):
    uploaded_file = st.sidebar.file_uploader('Upload Your File. Some File Might Not work', type=['csv', 'txt'])
    st.sidebar.markdown('[Example CSV and TXT file](https://raw.githubusercontent.com/codebasics/py/master/pandas/11_melt/weather.csv)')

    
# Profiling Report For Pandas

if uploaded_file is not None:
    @st.cache # Cache Function is used to save dataset and make it possible for run EDA WebAPP Fast
    
    # Create A function to load CSV file
    
    def load_csv():
        csv = pd.read_csv(uploaded_file)
        return csv
    df = load_csv()
    pr = ProfileReport(df, explorative=True)
    st.header('**1-Input Data Frame**')
    st.write(df)
    st.write('---')
    st.header('**2-Profiling Report With Pandas**')
    st_profile_report(pr)

else:
    
    st.info('Waiting To Upload .CSV or .TXT File')
    
    # Create Sample Data Button If You have no Dataset
    
    if st.button('Press This Button To Perform EDA on Sample Data'):
        
        # Create Function To Create Sample Data and Load it to perform EDA Function
        
        def load_csv():
            data = pd.DataFrame(np.random.rand(100,5), columns=['Apple', 'Bat', 'Cat', 'Dog', 'Eye'])
            return data
        df = load_csv()
        pr = ProfileReport(df, explorative=True)
        st.header('**1-Input Data Frame**')
        st.write(df)
        st.write('---')
        st.header('**2-Profiling Report With Pandas**')
        st_profile_report(pr)
        st.subheader('Bar Chart Of Sample Dataset')
        st.bar_chart(df.head())
        st.subheader('Line Chart Of Sample Dataset')
        st.line_chart(df.head())
# Out:
# Overwriting EDA_Web_Application.py

# %%
# %%writefile Machine_Learning_Web_App.py

#import libraries

import streamlit as st
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score


# Header 

st.header('**Machine Learning Web APP**')
st.markdown('''
**Explore The 3 Different datasets in 3 Different Machine Learning Classifiers**
''')


# Datasets Names

dataset_name = st.sidebar.selectbox('Choose The Dataset Name', ('Iris', 'Breast Cancer', 'Wine'))

#Classifiers Names

classifier_name = st.sidebar.selectbox('Choose The Classifier Name', ('SVM', 'KNN', 'Random Forest'))


#Load Datasets (For Loading 3 Different datasets, We have to create Custom Function)

def get_dataset(dataset_name):
    data = None
    if dataset_name == 'Iris':
        data = datasets.load_iris()
    elif dataset_name == 'Breast Cancer':
        data = datasets.load_breast_cancer()
    else:
        data= datasets.load_wine()
    x= data.data
    y= data.target
    return x,y

# Call The Get_Dataset_Function

x,y = get_dataset(dataset_name)


# Display Shape & Classes of Datasets

st.write('Shape of Dataset : ', x.shape)
st.write('Number of Classes in Dataset :', len(np.unique(y)))


# Parameters Of Different Machine Learning Classifiers

def add_parameters(classifier_name):
    parameters = dict()
    if classifier_name == 'SVM':
        C= st.sidebar.slider('c', 0.01,10.0)
        parameters['c']=C
    elif classifier_name == 'KNN':
        K = st.sidebar.slider('K', 1,15)
        parameters['K']=K
    else:
        max_depth = st.sidebar.slider('max_depth', 2,15)
        parameters['max_depth']= max_depth
        n_estimators = st.sidebar.slider('n_estimators', 1,100)
        parameters['n_estimators']= n_estimators
    return parameters    


# Call The Slider Parameter Function 

parameters = add_parameters(classifier_name)


# Create Classifiers On the Basis of Classifier Name and Parameters

def get_classifier(classifier_name, parameters):
    classifier = None
    
    if classifier_name=='SVM':
        classifier = SVC(C=parameters['c'])
    elif classifier_name=='KNN':
        classifier = KNeighborsClassifier(n_neighbors=parameters['K'])
    else:
        classifier= RandomForestClassifier(n_estimators=parameters['n_estimators'],
                                          max_depth=parameters['max_depth'],
                                          random_state=1234)
    return classifier    


# Call Get Classifier Function

classifier = get_classifier(classifier_name, parameters)

# Split The Dataset

X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=32)

# Train The Classifier

classifier.fit(X_train, Y_train)

y_pred = classifier.predict(X_test)

# Check Model Accuracy 

accuracy = accuracy_score(Y_test,y_pred)
st.write(f'Classifier = {classifier_name}')
st.write('Accuracy =', accuracy)


# Plot The Dataset Using PCA

pca = PCA(2)
X_projected = pca.fit_transform(x)

   ## Slice The Dimension
x1 = X_projected[:,0]
x2 = X_projected[:,1]

fig = plt.figure(figsize=(11,3))
fig.patch.set_facecolor('grey')
plt.rcParams['axes.facecolor'] = 'orange'

plt.scatter(x1,x2,c=y,alpha=0.8,cmap='viridis')
plt.xlabel('Principle Component 1', color='white')
plt.ylabel('Principle Component 2', color='white')
plt.colorbar()

# Show The Plot

st.pyplot(fig)
# Out:
# Overwriting Machine_Learning_Web_App.py

# %%
pip install streamlit-embedcode
# Out:
# Collecting streamlit-embedcode
#   Downloading streamlit_embedcode-0.1.2-py3-none-any.whl (3.5 kB)
# Requirement already satisfied: streamlit>=0.63 in d:\annaconda\lib\site-packages (from streamlit-embedcode) (1.12.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (4.1.1)
# Requirement already satisfied: click>=7.0 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (8.0.4)
# Requirement already satisfied: rich>=10.11.0 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (12.5.1)
# Requirement already satisfied: cachetools>=4.0 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (4.2.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (9.0.1)
# Requirement already satisfied: gitpython!=3.1.19 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (3.1.27)
# Requirement already satisfied: pydeck>=0.1.dev5 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (0.7.1)
# Requirement already satisfied: pympler>=0.9 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (1.0.1)
# Requirement already satisfied: tzlocal>=1.1 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (4.2)
# Requirement already satisfied: pyarrow>=4.0 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (9.0.0)
# Requirement already satisfied: pandas>=0.21.0 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (1.4.2)
# Requirement already satisfied: validators>=0.2 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (0.20.0)
# Requirement already satisfied: importlib-metadata>=1.4 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (4.11.3)
# Requirement already satisfied: altair>=3.2.0 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (4.2.0)
# Requirement already satisfied: packaging>=14.1 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (21.3)
# Requirement already satisfied: numpy in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (1.21.5)
# Requirement already satisfied: semver in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (2.13.0)
# Requirement already satisfied: toml in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (0.10.2)
# Requirement already satisfied: tornado>=5.0 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (6.1)
# Requirement already satisfied: python-dateutil in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (2.8.2)
# Requirement already satisfied: watchdog in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (2.1.6)
# Requirement already satisfied: protobuf<4,>=3.12 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (3.19.1)
# Requirement already satisfied: requests>=2.4 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (2.27.1)
# Requirement already satisfied: blinker>=1.0.0 in d:\annaconda\lib\site-packages (from streamlit>=0.63->streamlit-embedcode) (1.5)
# Requirement already satisfied: jsonschema>=3.0 in d:\annaconda\lib\site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-embedcode) (4.4.0)
# Requirement already satisfied: jinja2 in d:\annaconda\lib\site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-embedcode) (2.11.3)
# Requirement already satisfied: entrypoints in d:\annaconda\lib\site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-embedcode) (0.4)
# Requirement already satisfied: toolz in d:\annaconda\lib\site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-embedcode) (0.11.2)
# Requirement already satisfied: colorama in d:\annaconda\lib\site-packages (from click>=7.0->streamlit>=0.63->streamlit-embedcode) (0.4.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\annaconda\lib\site-packages (from gitpython!=3.1.19->streamlit>=0.63->streamlit-embedcode) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\annaconda\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit>=0.63->streamlit-embedcode) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in d:\annaconda\lib\site-packages (from importlib-metadata>=1.4->streamlit>=0.63->streamlit-embedcode) (3.7.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: attrs>=17.4.0 in d:\annaconda\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.63->streamlit-embedcode) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\annaconda\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.63->streamlit-embedcode) (0.18.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\annaconda\lib\site-packages (from packaging>=14.1->streamlit>=0.63->streamlit-embedcode) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in d:\annaconda\lib\site-packages (from pandas>=0.21.0->streamlit>=0.63->streamlit-embedcode) (2021.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in d:\annaconda\lib\site-packages (from pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (7.6.5)
# Requirement already satisfied: ipykernel>=5.1.2 in d:\annaconda\lib\site-packages (from pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (6.9.1)
# Requirement already satisfied: traitlets>=4.3.2 in d:\annaconda\lib\site-packages (from pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (5.1.1)
# Requirement already satisfied: ipython>=7.23.1 in d:\annaconda\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (8.2.0)
# Requirement already satisfied: jupyter-client<8.0 in d:\annaconda\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in d:\annaconda\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.1.2)
# Requirement already satisfied: nest-asyncio in d:\annaconda\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (1.5.5)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in d:\annaconda\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (1.5.1)
# Requirement already satisfied: pygments>=2.4.0 in d:\annaconda\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (2.11.2)
# Requirement already satisfied: pickleshare in d:\annaconda\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in d:\annaconda\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.18.1)
# Requirement already satisfied: backcall in d:\annaconda\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in d:\annaconda\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (61.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\annaconda\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (3.0.20)
# Requirement already satisfied: stack-data in d:\annaconda\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.2.0)
# Requirement already satisfied: decorator in d:\annaconda\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in d:\annaconda\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in d:\annaconda\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in d:\annaconda\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (5.3.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\annaconda\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (3.5.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\annaconda\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\annaconda\lib\site-packages (from jinja2->altair>=3.2.0->streamlit>=0.63->streamlit-embedcode) (2.0.1)
# Requirement already satisfied: pyzmq>=13 in d:\annaconda\lib\site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in d:\annaconda\lib\site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (4.9.2)
# Requirement already satisfied: pywin32>=1.0 in d:\annaconda\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (302)
# Requirement already satisfied: fastjsonschema in d:\annaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (2.15.1)
# Requirement already satisfied: wcwidth in d:\annaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.2.5)
# Requirement already satisfied: six>=1.5 in d:\annaconda\lib\site-packages (from python-dateutil->streamlit>=0.63->streamlit-embedcode) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\annaconda\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit-embedcode) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\annaconda\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit-embedcode) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\annaconda\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit-embedcode) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\annaconda\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit-embedcode) (3.3)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in d:\annaconda\lib\site-packages (from rich>=10.11.0->streamlit>=0.63->streamlit-embedcode) (0.9.1)
# Requirement already satisfied: tzdata in d:\annaconda\lib\site-packages (from tzlocal>=1.1->streamlit>=0.63->streamlit-embedcode) (2022.2)
# Requirement already satisfied: pytz-deprecation-shim in d:\annaconda\lib\site-packages (from tzlocal>=1.1->streamlit>=0.63->streamlit-embedcode) (0.1.0.post0)
# Requirement already satisfied: notebook>=4.4.1 in d:\annaconda\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (6.4.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in d:\annaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (1.8.0)
# Requirement already satisfied: nbconvert in d:\annaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (6.4.4)
# Requirement already satisfied: terminado>=0.8.3 in d:\annaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.13.1)
# Requirement already satisfied: prometheus-client in d:\annaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.13.1)
# Requirement already satisfied: argon2-cffi in d:\annaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in d:\annaconda\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in d:\annaconda\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\annaconda\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (1.15.0)
# Requirement already satisfied: pycparser in d:\annaconda\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (2.21)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in d:\annaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\annaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\annaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.8.4)
# Requirement already satisfied: defusedxml in d:\annaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\annaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.1.2)
# Requirement already satisfied: beautifulsoup4 in d:\annaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (4.11.1)
# Requirement already satisfied: testpath in d:\annaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.5.0)
# Requirement already satisfied: bleach in d:\annaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (4.1.0)
# Requirement already satisfied: soupsieve>1.2 in d:\annaconda\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (2.3.1)
# Requirement already satisfied: webencodings in d:\annaconda\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.5.1)
# Requirement already satisfied: asttokens in d:\annaconda\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (2.0.5)
# Requirement already satisfied: executing in d:\annaconda\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.8.3)
# Requirement already satisfied: pure-eval in d:\annaconda\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-embedcode) (0.2.2)
# Installing collected packages: streamlit-embedcode
# Successfully installed streamlit-embedcode-0.1.2

# %%
# %%writefile Machine_Learning_Web_APP_Updated.py

# Import Libraries
import streamlit as st
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from streamlit_embedcode import github_gist

# Header

st.header('**Machine Learning Web App**')
st.markdown('''
**Explore The 3 Different Machine Learning Models with 3 Different Datasets**
''')

# Dataset Names

dataset_name = st.sidebar.selectbox('Choose The Dataset', ('Iris', 'Breast Cancer','Wine'))

# Classifier Name

classifier_name = st.sidebar.selectbox('Choose The Classifier', ('SVM', 'KNN', 'Random Forest'))


# Load The Dataset (For Loading The Dataset, We have to create Custom Function)

def get_data(dataset_name):
    data = None
    if dataset_name == 'Iris':
        data = datasets.load_iris()
    elif dataset_name == 'Breast Cancer':
        data = datasets.load_breast_cancer()
    else:
        data = datasets.load_wine()
    x = data.data
    y = data.target
    return x,y

# Call The Get_data Function

x, y = get_data(dataset_name)

# Display Shape and Number Of Classes

st.write('Shape of Dataset :', x.shape )
st.write('Number Of Classes in Dataset :', len(np.unique(y)))

# Parameters of Different Machine Learning Classifiers

def add_parameters(classifier_name):
    parameters = dict()
    if classifier_name == 'SVM':
        C = st.sidebar.slider('c', 0.01,10.0)
        parameters['c'] = C
    elif classifier_name == 'KNN':
        K = st.sidebar.slider('K',1,15)
        parameters['K']= K
    else:
        max_depth = st.sidebar.slider('max_depth',2,15)
        parameters['max_depth']= max_depth
        n_estimators = st.sidebar.slider('n_estimators', 1,100)
        parameters['n_estimators'] = n_estimators
    return parameters

# Call The Add Parameter Slider Function

parameters = add_parameters(classifier_name)


# Create Classifier on the basis of classifier name and parameters

def get_classifier(classifier_name, parameters):
    classifier = None
    if classifier_name == 'SVM':
        classifier = SVC(C=parameters['c'])
    elif classifier_name == 'KNN':
        classifier = KNeighborsClassifier(n_neighbors=parameters['K'])
    else:
        classifier = RandomForestClassifier(n_estimators=parameters['n_estimators'],
                                            max_depth=parameters['max_depth'],
                                           random_state=1234)
    return classifier    

# Call The Get Classifier

classifier = get_classifier(classifier_name, parameters)


# Split The Dataset
X_train, X_test , Y_train,Y_test = train_test_split(x,y, test_size=0.2,random_state=32)

# Train The Classifier

classifier.fit(X_train, Y_train)
Y_pred = classifier.predict(X_test)


# Check Model Accuracy

accuracy = accuracy_score(Y_test, Y_pred)
st.write(f"Classifier = {classifier_name}")
st.write('Accuracy Score is :', accuracy)

 # Plot The Dataset Using PCA
pca = PCA(2)
X_projected = pca.fit_transform(x)

   ## Slice The Dimension
x1 = X_projected[:,0]
x2 = X_projected[:,1]

fig = plt.figure(figsize=(11,3))
fig.patch.set_facecolor('grey')
plt.rcParams['axes.facecolor'] = 'orange'

plt.scatter(x1,x2,c=y,alpha=0.8,cmap='viridis')
plt.xlabel('Principle Component 1', color='white')
plt.ylabel('Principle Component 2', color='white')
plt.colorbar()

# Show The Plot

st.pyplot(fig)

link = 'https://gist.github.com/Mabtoor-Mabx/de3b985ffcba0fffeee68dee2e97246c'
github_gist(link, height=400, width=800)
    
    
  ####-----------------------------------------------------------------------------#######

# Show Code if Someone wants to display code of this app

if st.checkbox('Show Code'):
    with st.echo():
        # Import Libraries
        import streamlit as st
        import numpy as np
        import pandas as pd
        import matplotlib.pyplot as plt
        import seaborn as sns
        from sklearn import datasets
        from sklearn.model_selection import train_test_split
        from sklearn.decomposition import PCA
        from sklearn.svm import SVC
        from sklearn.neighbors import KNeighborsClassifier
        from sklearn.ensemble import RandomForestClassifier
        from sklearn.metrics import accuracy_score
        
        
        
        # Load The Dataset (For Loading The Dataset, We have to create Custom Function)

        def get_data(dataset_name):
            data = None
            if dataset_name == 'Iris':
                data = datasets.load_iris()
            elif dataset_name == 'Breast Cancer':
                data = datasets.load_breast_cancer()
            else:
                data = datasets.load_wine()
            x = data.data
            y = data.target
            return x,y
        
        # Parameters of Different Machine Learning Classifiers

        def add_parameters(classifier_name):
            parameters = dict()
            if classifier_name == 'SVM':
                C = st.sidebar.slider('c', 0.01,10.0)
                parameters['c'] = C
            elif classifier_name == 'KNN':
                K = st.sidebar.slider('K',1,15)
                parameters['K']= K
            else:
                max_depth = st.sidebar.slider('max_depth',2,15)
                parameters['max_depth']= max_depth
                n_estimators = st.sidebar.slider('n_estimators', 1,100)
                parameters['n_estimators'] = n_estimators
            return parameters
        
        
        # Get Classifier Function
        def get_classifier(classifier_name, parameters):
            classifier = None
            if classifier_name == 'SVM':
                classifier = SVC(C=parameters['c'])
            elif classifier_name == 'KNN':
                classifier = KNeighborsClassifier(n_neighbors=parameters['K'])
            else:
                classifier = RandomForestClassifier(n_estimators=parameters['n_estimators'],
                                                    max_depth=parameters['max_depth'],
                                                   random_state=1234)
            return classifier    
        
        
        # Split The Dataset
        X_train, X_test , Y_train,Y_test = train_test_split(x,y, test_size=0.2,random_state=32)

        # Train The Classifier

        classifier.fit(X_train, Y_train)
        Y_pred = classifier.predict(X_test)


        # Check Model Accuracy

        accuracy = accuracy_score(Y_test, Y_pred)
# Out:
# Overwriting Machine_Learning_Web_APP_Updated.py

# %%
# !pip install explainerdashboard
# Out:
# Collecting explainerdashboard
#   Downloading explainerdashboard-0.4.0-py3-none-any.whl (279 kB)
# Requirement already satisfied: numpy in d:\annaconda\lib\site-packages (from explainerdashboard) (1.21.5)
# Collecting dash-bootstrap-components>=1
#   Downloading dash_bootstrap_components-1.2.1-py3-none-any.whl (216 kB)
# Requirement already satisfied: click in d:\annaconda\lib\site-packages (from explainerdashboard) (8.0.4)
# Collecting jupyter-dash
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Collecting shap>=0.37
#   Downloading shap-0.41.0-cp39-cp39-win_amd64.whl (435 kB)
# Collecting dtreeviz>=1.3
#   Downloading dtreeviz-1.3.7.tar.gz (62 kB)
# Collecting oyaml
#   Downloading oyaml-1.0-py2.py3-none-any.whl (3.0 kB)
# Requirement already satisfied: pandas>=1.1 in d:\annaconda\lib\site-packages (from explainerdashboard) (1.4.2)
# Collecting dash-auth
#   Downloading dash_auth-1.4.1.tar.gz (470 kB)
# Collecting waitress
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
# Requirement already satisfied: dash>=2.3.1 in d:\annaconda\lib\site-packages (from explainerdashboard) (2.6.1)
# Requirement already satisfied: joblib in d:\annaconda\lib\site-packages (from explainerdashboard) (1.1.0)
# Collecting flask-simplelogin
#   Downloading flask_simplelogin-0.1.1-py3-none-any.whl (7.2 kB)
# Collecting scikit-learn>=1.1
#   Downloading scikit_learn-1.1.2-cp39-cp39-win_amd64.whl (7.4 MB)
# Collecting graphviz>=0.18.2
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
# Requirement already satisfied: dash-table==5.0.0 in d:\annaconda\lib\site-packages (from dash>=2.3.1->explainerdashboard) (5.0.0)
# Requirement already satisfied: Flask>=1.0.4 in d:\annaconda\lib\site-packages (from dash>=2.3.1->explainerdashboard) (1.1.2)
# Requirement already satisfied: dash-html-components==2.0.0 in d:\annaconda\lib\site-packages (from dash>=2.3.1->explainerdashboard) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in d:\annaconda\lib\site-packages (from dash>=2.3.1->explainerdashboard) (5.10.0)
# Requirement already satisfied: dash-core-components==2.0.0 in d:\annaconda\lib\site-packages (from dash>=2.3.1->explainerdashboard) (2.0.0)
# Requirement already satisfied: flask-compress in d:\annaconda\lib\site-packages (from dash>=2.3.1->explainerdashboard) (1.12)
# Requirement already satisfied: matplotlib in d:\annaconda\lib\site-packages (from dtreeviz>=1.3->explainerdashboard) (3.5.1)
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pytest in d:\annaconda\lib\site-packages (from dtreeviz>=1.3->explainerdashboard) (7.1.1)
# Requirement already satisfied: Jinja2>=2.10.1 in d:\annaconda\lib\site-packages (from Flask>=1.0.4->dash>=2.3.1->explainerdashboard) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in d:\annaconda\lib\site-packages (from Flask>=1.0.4->dash>=2.3.1->explainerdashboard) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in d:\annaconda\lib\site-packages (from Flask>=1.0.4->dash>=2.3.1->explainerdashboard) (2.0.1)
# Requirement already satisfied: colorama in d:\annaconda\lib\site-packages (from click->explainerdashboard) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\annaconda\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash>=2.3.1->explainerdashboard) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\annaconda\lib\site-packages (from pandas>=1.1->explainerdashboard) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\annaconda\lib\site-packages (from pandas>=1.1->explainerdashboard) (2021.3)
# Requirement already satisfied: tenacity>=6.2.0 in d:\annaconda\lib\site-packages (from plotly>=5.0.0->dash>=2.3.1->explainerdashboard) (8.0.1)
# Requirement already satisfied: six>=1.5 in d:\annaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.1->explainerdashboard) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\annaconda\lib\site-packages (from scikit-learn>=1.1->explainerdashboard) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in d:\annaconda\lib\site-packages (from scikit-learn>=1.1->explainerdashboard) (1.7.3)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in d:\annaconda\lib\site-packages (from shap>=0.37->explainerdashboard) (0.55.1)
# Requirement already satisfied: packaging>20.9 in d:\annaconda\lib\site-packages (from shap>=0.37->explainerdashboard) (21.3)
# Requirement already satisfied: cloudpickle in d:\annaconda\lib\site-packages (from shap>=0.37->explainerdashboard) (2.0.0)
# Requirement already satisfied: tqdm>4.25.0 in d:\annaconda\lib\site-packages (from shap>=0.37->explainerdashboard) (4.64.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\annaconda\lib\site-packages (from packaging>20.9->shap>=0.37->explainerdashboard) (3.0.4)
# Collecting chart_studio>=1.0.0
#   Downloading chart_studio-1.1.0-py3-none-any.whl (64 kB)
# Collecting flask-seasurf
#   Downloading Flask_SeaSurf-1.1.1-py3-none-any.whl (8.4 kB)
# Requirement already satisfied: requests in d:\annaconda\lib\site-packages (from dash-auth->explainerdashboard) (2.27.1)
# Collecting retrying
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Collecting ua_parser
#   Downloading ua_parser-0.16.1-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: brotli in d:\annaconda\lib\site-packages (from flask-compress->dash>=2.3.1->explainerdashboard) (1.0.9)
# Collecting WTForms>=2.1
#   Downloading WTForms-3.0.1-py3-none-any.whl (136 kB)
# Collecting Flask-WTF<0.16.0,>=0.15.1
#   Downloading Flask_WTF-0.15.1-py2.py3-none-any.whl (13 kB)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: ipython in d:\annaconda\lib\site-packages (from jupyter-dash->explainerdashboard) (8.2.0)
# Requirement already satisfied: ipykernel in d:\annaconda\lib\site-packages (from jupyter-dash->explainerdashboard) (6.9.1)
# Requirement already satisfied: nest-asyncio in d:\annaconda\lib\site-packages (from jupyter-dash->explainerdashboard) (1.5.5)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in d:\annaconda\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in d:\annaconda\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in d:\annaconda\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in d:\annaconda\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (6.1.12)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in d:\annaconda\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (5.1.1)
# Requirement already satisfied: pickleshare in d:\annaconda\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\annaconda\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (3.0.20)
# Requirement already satisfied: stack-data in d:\annaconda\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (0.2.0)
# Requirement already satisfied: backcall in d:\annaconda\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in d:\annaconda\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (2.11.2)
# Requirement already satisfied: setuptools>=18.5 in d:\annaconda\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (61.2.0)
# Requirement already satisfied: decorator in d:\annaconda\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\annaconda\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\annaconda\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash->explainerdashboard) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in d:\annaconda\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash->explainerdashboard) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in d:\annaconda\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash->explainerdashboard) (4.9.2)
# Requirement already satisfied: pywin32>=1.0 in d:\annaconda\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter-dash->explainerdashboard) (302)
# Requirement already satisfied: wcwidth in d:\annaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash->explainerdashboard) (0.2.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\annaconda\lib\site-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in d:\annaconda\lib\site-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in d:\annaconda\lib\site-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\annaconda\lib\site-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (9.0.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in d:\annaconda\lib\site-packages (from numba->shap>=0.37->explainerdashboard) (0.38.0)
# Requirement already satisfied: pyyaml in d:\annaconda\lib\site-packages (from oyaml->explainerdashboard) (6.0)
# Requirement already satisfied: attrs>=19.2.0 in d:\annaconda\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (21.4.0)
# Requirement already satisfied: iniconfig in d:\annaconda\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in d:\annaconda\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in d:\annaconda\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in d:\annaconda\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (1.2.2)
# Requirement already satisfied: atomicwrites>=1.0 in d:\annaconda\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (1.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\annaconda\lib\site-packages (from requests->dash-auth->explainerdashboard) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\annaconda\lib\site-packages (from requests->dash-auth->explainerdashboard) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\annaconda\lib\site-packages (from requests->dash-auth->explainerdashboard) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\annaconda\lib\site-packages (from requests->dash-auth->explainerdashboard) (2021.10.8)
# Requirement already satisfied: executing in d:\annaconda\lib\site-packages (from stack-data->ipython->jupyter-dash->explainerdashboard) (0.8.3)
# Requirement already satisfied: asttokens in d:\annaconda\lib\site-packages (from stack-data->ipython->jupyter-dash->explainerdashboard) (2.0.5)
# Requirement already satisfied: pure-eval in d:\annaconda\lib\site-packages (from stack-data->ipython->jupyter-dash->explainerdashboard) (0.2.2)
# Building wheels for collected packages: dtreeviz, dash-auth, retrying
#   Building wheel for dtreeviz (setup.py): started
#   Building wheel for dtreeviz (setup.py): finished with status 'done'
#   Created wheel for dtreeviz: filename=dtreeviz-1.3.7-py3-none-any.whl size=68151 sha256=ca3962ac55a0e28d97dd26defb8f1ee7c37a263bb32c84cb35c2eadac3573286
#   Stored in directory: c:\users\mabtoor mabx\appdata\local\pip\cache\wheels\94\4d\ca\df6b7427d49df660c50c351242463476c3f7935c359402e42b
#   Building wheel for dash-auth (setup.py): started
#   Building wheel for dash-auth (setup.py): finished with status 'done'
#   Created wheel for dash-auth: filename=dash_auth-1.4.1-py3-none-any.whl size=476152 sha256=ee8ffa5399bc391355fbb0af698990e50f22e6d276f625edb30d2d01168f4b18
#   Stored in directory: c:\users\mabtoor mabx\appdata\local\pip\cache\wheels\e8\57\2b\aba4cf993de295833eef8d0679fe5fb52b60b8efa1fa3808f4
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11447 sha256=066a2af1cf214d1323e8ed383e795eb44363f09c0e5212f902da29a11eb3a010
#   Stored in directory: c:\users\mabtoor mabx\appdata\local\pip\cache\wheels\ce\18\7f\e9527e3e66db1456194ac7f61eb3211068c409edceecff2d31
# Successfully built dtreeviz dash-auth retrying
# Installing collected packages: WTForms, retrying, ua-parser, slicer, scikit-learn, graphviz, Flask-WTF, flask-seasurf, colour, chart-studio, ansi2html, waitress, shap, oyaml, jupyter-dash, flask-simplelogin, dtreeviz, dash-bootstrap-components, dash-auth, explainerdashboard
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# Successfully installed Flask-WTF-0.15.1 WTForms-3.0.1 ansi2html-1.8.0 chart-studio-1.1.0 colour-0.1.5 dash-auth-1.4.1 dash-bootstrap-components-1.2.1 dtreeviz-1.3.7 explainerdashboard-0.4.0 flask-seasurf-1.1.1 flask-simplelogin-0.1.1 graphviz-0.20.1 jupyter-dash-0.4.2 oyaml-1.0 retrying-1.3.3 scikit-learn-1.1.2 shap-0.41.0 slicer-0.0.7 ua-parser-0.16.1 waitress-2.1.2

# %%
# %%writefile interactive_dashboard.py

# Import Libraries
from sklearn.ensemble import RandomForestClassifier
from explainerdashboard import ClassifierExplainer, ExplainerDashboard
from explainerdashboard.datasets import titanic_survive, feature_descriptions

# Load and Split Dataset

X_train,Y_train,X_test,Y_test = titanic_survive()

# Load Machine Learning Model

model =  RandomForestClassifier().fit(X_train,Y_train)

explainer = ClassifierExplainer(model,
                                X_test,
                                Y_test,
                                cats=['Sex', 'Deck', 'Embarked'],
                                descriptions=feature_descriptions,
                                labels=['not_survived', 'survived']
                               )

ExplainerDashboard(explainer).run()
# Out:
# Overwriting interactive_dashboard.py

# %%
# %%writefile audio_and_video.py

# Import Libraries

import streamlit as st
from PIL import Image

# Heading 

st.header('Add Image, Audio and Video in Streamlit')

# Add Image
st.subheader('Cat Image')
images = Image.open('cat.jpg')
st.image(images)

# Add Video
st.subheader('Cat Video')
videos = open('cat.mp4','rb')
st.video(videos)

# Add Audio

st.subheader('Cat Audio')
audios = open('cat.mp3', 'rb')
st.audio(audios)
# Out:
# Overwriting audio_and_video.py
